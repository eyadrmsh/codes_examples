# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date
import datetime
import statsmodels.formula.api as smf
import statsmodels.api as sm
from tqdm.auto import tqdm
from scipy.stats import ttest_ind
import seaborn as sns
from sklearn.linear_model import LinearRegression

def event_occured(date, cutoff_date):
    if(date>=np.datetime64(cutoff_date)):
        return 1
    else:
        return 0

def days_from_event(x, cutoff_date):
    d1 = x
    d0 = datetime.datetime.strptime(cutoff_date,'%Y-%m-%d').date()
    delta = d1 - d0
    return delta.days

# %%
df_en = pd.read_pickle('balenciaga3.pkl')

# %% [markdown]
# ### Step 1: Performing t-tests and analyzing peaks

# %% [markdown]
# The RDD window usually happens to be a 1-day one which makes us go from days to hours in terms of time intervals. This is an unreliable time interval since different news sources have press-releases at different times of the day. Thus, we were forced to set the intervals equal to 1 day.
#
# To solve the issues above, we first detect the jumps using the t-tests. We construct the 2-sample t-test for every two days in a row and compare the brand perception metrics for these two days. In case we find that the t-statistic is significant, we mark the second day as the day with a jump. Figure 4 shows the graph of the t-statistic changes in time. The orange and the green lines represent the cut-offs, under which the t-statistic is insignificant. We set the cut-off to be symmetric and equal to 20 in order to filter 14 most outstanding PR moves or failures.

# %%
df_en['date'] = df_en['created_at'].apply(lambda x: x.date())
dates = sorted(df_en['date'].unique().tolist())

# %%
## compound is a the sentiment score
res = []

for i in tqdm(range(len(dates)-1)):
    date1 = dates[i]
    date2 = dates[i+1]
    
    df1 = df_en[df_en['date'] == date1]
    df2 = df_en[df_en['date'] == date2]
    
    res.append([date2, ttest_ind(df1['compound'], 
                                df2['compound'], equal_var=False)])
    
res_ = pd.DataFrame(res)
res_.columns = ['jump_date', 'test_results']
res_['t-stat'] = res_['test_results'].apply(lambda x: x[0])
res_['p-val'] = res_['test_results'].apply(lambda x: x[1])
# Out:
#   0%|          | 0/161 [00:00<?, ?it/s]

# %%
res_.head()
# Out:
#     jump_date                                 test_results    t-stat     p-val
# 0  2022-11-02    (1.7907215588328418, 0.07348965289113579)  1.790722  0.073490
# 1  2022-11-03   (-2.0146749621780637, 0.04399113727173747) -2.014675  0.043991
# 2  2022-11-04  (-4.412575583730974, 1.046427773573294e-05) -4.412576  0.000010
# 3  2022-11-05    (1.3843985574773754, 0.16632299332422834)  1.384399  0.166323
# 4  2022-11-06     (0.6286552894394707, 0.5296120765065396)  0.628655  0.529612

# %%
res_['line1'] = 20
res_['line2'] = -20

plt.figure(figsize=(10,6))

sns.lineplot(data=res_, x='jump_date', y='t-stat')
sns.lineplot(data=res_, x='jump_date', y='line1')
sns.lineplot(data=res_, x='jump_date', y='line2')
# Out:
# <AxesSubplot:xlabel='jump_date', ylabel='t-stat'>

# %%
jump_dates = [datetime.date(2022, 11, 1)] + \
            res_[(res_['t-stat']>20)|(res_['t-stat']<-20)]['jump_date'].unique().tolist() + \
                [datetime.date(2023, 4, 10)]

# %%
df_en['created_at_date'] = df_en['created_at'].dt.date

# %%
# creating a linear regression model for each sentiment score for each interval between events 

fig, axs = plt.subplots(4, 2, figsize=(10,20))
counter1 = 0
counter2 = 0

targets = ['compound', 'pos', 'neg', 'Angry', 'Sad', 'Surprise', 'Fear', 'Happy']

for target in targets:

    slopes = []

    for i in range(1, len(jump_dates)):
        date0 = jump_dates[i - 1]
        date1 = jump_dates[i]

        fin_df = df_en[(df_en['created_at_date'] < date1)&(df_en['created_at_date'] >= date0)]
    #     fin_df = fin_df[fin_df['neu']<0.5]
        dates = pd.DataFrame({'created_at_date':sorted(fin_df['created_at_date'].unique())}).reset_index()
        fin_df = fin_df.merge(dates, on = 'created_at_date')
        lr = LinearRegression()
        lr.fit(fin_df[['index']], fin_df[target])

        slopes.append([date0, date1, lr.coef_[0], lr.intercept_])

    slopes_ = pd.DataFrame(slopes)
    slopes_.columns = ['start', 'end', 'slope', 'intercept']

    dates = pd.DataFrame({'created_at_date':sorted(df_en['created_at_date'].unique())})

    for_graph = []

    for i in range(dates.shape[0]):
        for j in range(slopes_.shape[0]):
            if dates['created_at_date'][i] < slopes_['end'][j] and dates['created_at_date'][i] >= slopes_['start'][j]:
                diff = int(str(np.datetime64(dates['created_at_date'][i]) - \
                               np.datetime64(slopes_['start'][j])).replace(' days', ''))
                y = slopes_['slope'][j] * diff + slopes_['intercept'][j]
                for_graph.append([dates['created_at_date'][i], y])

    for_graph = pd.DataFrame(for_graph)
    for_graph.columns = ['date', target]

    plt.figure(figsize=(10,6))

    sns.lineplot(data=for_graph, x='date', y=target, ax = axs[counter1][counter2])
    axs[counter1][counter2].set_title(target)
    print(counter1, counter2)
    
    counter2 += 1
    
    if counter2 == 2:
        counter1 += 1
        counter2 = 0
        
# plt.show()
fig.savefig('Interval Analysis.jpg')
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1
# 3 0
# 3 1

# %% [markdown]
# For the cases where we are able to construct a window greater than 2 days, we use the RDD design to get more information not only about the difference in means, but also about the differences in the regressions’ slope coefficients with an estimate of statistical significance. We cannot take the amount of days equal to 2 or less, because we get into the case of matrix singularity in terms of days, while the hour time interval is unreliable
#
# Below we are calculating slope coefficients for each emotion,

# %%
indices = [1, 6, 13, 14]

for cutoff_index in indices:
    fin_df = df_en.copy()

    date0 = jump_dates[cutoff_index - 1]
    date1 = jump_dates[cutoff_index]
    date2 = jump_dates[cutoff_index + 1]
    
    days1 = int(str(np.datetime64(date1) - np.datetime64(date0)).replace(' days', ''))
    days2 = int(str(np.datetime64(date2) - np.datetime64(date1)).replace(' days', ''))

    window = min(days1, days2)

    fin_df = fin_df[(fin_df['created_at_date']>np.datetime64(date0))&
                    (fin_df['created_at_date']<np.datetime64(date2))]

    fin_df['after_event'] = fin_df.apply(lambda x: event_occured(x['created_at_date'], str(date1)), axis = 1)
    fin_df['days_from_event'] = fin_df.apply(lambda x: days_from_event(x['created_at_date'], str(date1)), axis = 1)
    
    fin_df['after_event'] = fin_df.apply(lambda x: event_occured(x['created_at_date'], str(date1)), axis = 1)
    fin_df['days_from_event'] = fin_df.apply(lambda x: days_from_event(x['created_at_date'], str(date1)), axis = 1)
    
    reg_df = fin_df[(fin_df['days_from_event'] >= -window)
                &(fin_df['days_from_event'] <= window)]

    for target in ['compound', 'neg', 'pos', 'Angry', 'Sad', 'Surprise', 'Fear', 'Happy']:

        result = smf.ols(formula = f"{target} ~ days_from_event + after_event + after_event * days_from_event", 
                         data = reg_df).fit()
        print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               compound   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     451.0
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          6.80e-291
# Time:                        18:28:41   Log-Likelihood:                -20173.
# No. Observations:               89696   AIC:                         4.035e+04
# Df Residuals:                   89692   BIC:                         4.039e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1055      0.005     20.177      0.000       0.095       0.116
# days_from_event                 0.0124      0.002      6.888      0.000       0.009       0.016
# after_event                     0.1252      0.006     19.584      0.000       0.113       0.138
# after_event:days_from_event    -0.0412      0.002    -19.920      0.000      -0.045      -0.037
# ==============================================================================
# Omnibus:                     2183.524   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4526.279
# Skew:                          -0.141   Prob(JB):                         0.00
# Kurtosis:                       4.064   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    neg   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     139.0
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):           7.09e-90
# Time:                        18:28:41   Log-Likelihood:             1.1383e+05
# No. Observations:               89696   AIC:                        -2.277e+05
# Df Residuals:                   89692   BIC:                        -2.276e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0039      0.001      3.324      0.001       0.002       0.006
# days_from_event                -0.0076      0.000    -18.810      0.000      -0.008      -0.007
# after_event                     0.0213      0.001     14.821      0.000       0.018       0.024
# after_event:days_from_event     0.0063      0.000     13.500      0.000       0.005       0.007
# ==============================================================================
# Omnibus:                    80486.795   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2432315.629
# Skew:                           4.434   Prob(JB):                         0.00
# Kurtosis:                      26.920   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pos   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     424.2
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          1.07e-273
# Time:                        18:28:41   Log-Likelihood:                 86598.
# No. Observations:               89696   AIC:                        -1.732e+05
# Df Residuals:                   89692   BIC:                        -1.732e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0498      0.002     31.307      0.000       0.047       0.053
# days_from_event                -0.0008      0.001     -1.543      0.123      -0.002       0.000
# after_event                     0.0475      0.002     24.417      0.000       0.044       0.051
# after_event:days_from_event    -0.0095      0.001    -15.091      0.000      -0.011      -0.008
# ==============================================================================
# Omnibus:                    31652.921   Durbin-Watson:                   1.745
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           108188.295
# Skew:                           1.806   Prob(JB):                         0.00
# Kurtosis:                       6.987   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Angry   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     68.97
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):           1.52e-44
# Time:                        18:28:41   Log-Likelihood:                 91703.
# No. Observations:               89696   AIC:                        -1.834e+05
# Df Residuals:                   89692   BIC:                        -1.834e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.0050      0.002     -3.342      0.001      -0.008      -0.002
# days_from_event                -0.0073      0.001    -14.031      0.000      -0.008      -0.006
# after_event                     0.0190      0.002     10.357      0.000       0.015       0.023
# after_event:days_from_event     0.0067      0.001     11.249      0.000       0.006       0.008
# ==============================================================================
# Omnibus:                   123236.064   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         22648283.278
# Skew:                           8.260   Prob(JB):                         0.00
# Kurtosis:                      79.073   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Sad   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     3375.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:28:42   Log-Likelihood:                -2768.5
# No. Observations:               89696   AIC:                             5545.
# Df Residuals:                   89692   BIC:                             5583.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2744      0.004     63.734      0.000       0.266       0.283
# days_from_event                 0.0260      0.001     17.529      0.000       0.023       0.029
# after_event                    -0.2444      0.005    -46.421      0.000      -0.255      -0.234
# after_event:days_from_event     0.0498      0.002     29.248      0.000       0.047       0.053
# ==============================================================================
# Omnibus:                     5364.576   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6864.356
# Skew:                           0.576   Prob(JB):                         0.00
# Kurtosis:                       3.715   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Surprise   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     517.2
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:28:42   Log-Likelihood:                -22801.
# No. Observations:               89696   AIC:                         4.561e+04
# Df Residuals:                   89692   BIC:                         4.565e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1138      0.005     21.134      0.000       0.103       0.124
# days_from_event                 0.0026      0.002      1.407      0.160      -0.001       0.006
# after_event                    -0.0514      0.007     -7.810      0.000      -0.064      -0.038
# after_event:days_from_event     0.0294      0.002     13.815      0.000       0.025       0.034
# ==============================================================================
# Omnibus:                    29496.065   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            72617.003
# Skew:                           1.887   Prob(JB):                         0.00
# Kurtosis:                       5.278   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fear   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     261.3
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          7.86e-169
# Time:                        18:28:42   Log-Likelihood:                -20745.
# No. Observations:               89696   AIC:                         4.150e+04
# Df Residuals:                   89692   BIC:                         4.153e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2841      0.005     54.002      0.000       0.274       0.294
# days_from_event                 0.0189      0.002     10.419      0.000       0.015       0.022
# after_event                     0.0091      0.006      1.419      0.156      -0.003       0.022
# after_event:days_from_event    -0.0434      0.002    -20.832      0.000      -0.047      -0.039
# ==============================================================================
# Omnibus:                    13857.524   Durbin-Watson:                   1.780
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21300.753
# Skew:                           1.180   Prob(JB):                         0.00
# Kurtosis:                       3.360   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Happy   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     2993.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:28:42   Log-Likelihood:                 5993.2
# No. Observations:               89696   AIC:                        -1.198e+04
# Df Residuals:                   89692   BIC:                        -1.194e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0127      0.004      3.244      0.001       0.005       0.020
# days_from_event                -0.0153      0.001    -11.325      0.000      -0.018      -0.013
# after_event                    -0.0250      0.005     -5.227      0.000      -0.034      -0.016
# after_event:days_from_event     0.0688      0.002     44.534      0.000       0.066       0.072
# ==============================================================================
# Omnibus:                    23093.834   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            55425.854
# Skew:                           1.440   Prob(JB):                         0.00
# Kurtosis:                       5.557   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               compound   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     4123.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:30:16   Log-Likelihood:            -1.8909e+05
# No. Observations:              380462   AIC:                         3.782e+05
# Df Residuals:                  380458   BIC:                         3.782e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.1311      0.003    -44.592      0.000      -0.137      -0.125
# days_from_event                 0.0335      0.002     19.238      0.000       0.030       0.037
# after_event                     0.0834      0.003     25.974      0.000       0.077       0.090
# after_event:days_from_event    -0.0204      0.003     -7.637      0.000      -0.026      -0.015
# ==============================================================================
# Omnibus:                     8912.072   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4708.292
# Skew:                           0.058   Prob(JB):                         0.00
# Kurtosis:                       2.468   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    neg   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     908.6
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:30:17   Log-Likelihood:             3.1877e+05
# No. Observations:              380462   AIC:                        -6.375e+05
# Df Residuals:                  380458   BIC:                        -6.375e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1188      0.001    153.568      0.000       0.117       0.120
# days_from_event                 0.0026      0.000      5.733      0.000       0.002       0.004
# after_event                    -0.0253      0.001    -29.964      0.000      -0.027      -0.024
# after_event:days_from_event     0.0134      0.001     19.057      0.000       0.012       0.015
# ==============================================================================
# Omnibus:                    52025.134   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            84530.356
# Skew:                           0.945   Prob(JB):                         0.00
# Kurtosis:                       4.327   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pos   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     3284.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:30:17   Log-Likelihood:             4.1361e+05
# No. Observations:              380462   AIC:                        -8.272e+05
# Df Residuals:                  380458   BIC:                        -8.272e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0736      0.001    122.013      0.000       0.072       0.075
# days_from_event                 0.0140      0.000     39.171      0.000       0.013       0.015
# after_event                     0.0001      0.001      0.161      0.872      -0.001       0.001
# after_event:days_from_event    -0.0101      0.001    -18.379      0.000      -0.011      -0.009
# ==============================================================================
# Omnibus:                    88292.226   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           191415.969
# Skew:                           1.349   Prob(JB):                         0.00
# Kurtosis:                       5.190   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Angry   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     452.9
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          9.24e-294
# Time:                        18:30:17   Log-Likelihood:             1.6582e+05
# No. Observations:              380462   AIC:                        -3.316e+05
# Df Residuals:                  380458   BIC:                        -3.316e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0719      0.001     62.190      0.000       0.070       0.074
# days_from_event                 0.0127      0.001     18.541      0.000       0.011       0.014
# after_event                    -0.0301      0.001    -23.791      0.000      -0.033      -0.028
# after_event:days_from_event    -0.0247      0.001    -23.529      0.000      -0.027      -0.023
# ==============================================================================
# Omnibus:                   330247.231   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7892727.075
# Skew:                           4.316   Prob(JB):                         0.00
# Kurtosis:                      23.576   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Sad   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     2118.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:30:17   Log-Likelihood:                -74601.
# No. Observations:              380462   AIC:                         1.492e+05
# Df Residuals:                  380458   BIC:                         1.493e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1341      0.002     61.653      0.000       0.130       0.138
# days_from_event                -0.0305      0.001    -23.660      0.000      -0.033      -0.028
# after_event                     0.0883      0.002     37.165      0.000       0.084       0.093
# after_event:days_from_event     0.0895      0.002     45.237      0.000       0.086       0.093
# ==============================================================================
# Omnibus:                    60855.189   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94432.393
# Skew:                           1.193   Prob(JB):                         0.00
# Kurtosis:                       3.511   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Surprise   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     192.7
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          7.31e-125
# Time:                        18:30:17   Log-Likelihood:                -90634.
# No. Observations:              380462   AIC:                         1.813e+05
# Df Residuals:                  380458   BIC:                         1.813e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1605      0.002     70.739      0.000       0.156       0.165
# days_from_event                -0.0311      0.001    -23.160      0.000      -0.034      -0.028
# after_event                     0.0437      0.002     17.639      0.000       0.039       0.049
# after_event:days_from_event     0.0401      0.002     19.460      0.000       0.036       0.044
# ==============================================================================
# Omnibus:                    84779.673   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           154289.622
# Skew:                           1.459   Prob(JB):                         0.00
# Kurtosis:                       4.106   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fear   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     202.6
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          2.50e-131
# Time:                        18:30:18   Log-Likelihood:            -1.3560e+05
# No. Observations:              380462   AIC:                         2.712e+05
# Df Residuals:                  380458   BIC:                         2.713e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2775      0.003    108.651      0.000       0.272       0.282
# days_from_event                -0.0132      0.002     -8.708      0.000      -0.016      -0.010
# after_event                    -0.0055      0.003     -1.960      0.050      -0.011   -1.15e-06
# after_event:days_from_event     0.0146      0.002      6.300      0.000       0.010       0.019
# ==============================================================================
# Omnibus:                    43990.550   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            58167.174
# Skew:                           0.942   Prob(JB):                         0.00
# Kurtosis:                       2.649   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Happy   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     1020.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:30:18   Log-Likelihood:             1.6900e+05
# No. Observations:              380462   AIC:                        -3.380e+05
# Df Residuals:                  380458   BIC:                        -3.379e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0391      0.001     34.063      0.000       0.037       0.041
# days_from_event                -0.0134      0.001    -19.671      0.000      -0.015      -0.012
# after_event                     0.0027      0.001      2.186      0.029       0.000       0.005
# after_event:days_from_event    -0.0009      0.001     -0.910      0.363      -0.003       0.001
# ==============================================================================
# Omnibus:                   288732.034   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4536375.199
# Skew:                           3.684   Prob(JB):                         0.00
# Kurtosis:                      18.228   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               compound   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     299.9
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          4.74e-194
# Time:                        18:31:03   Log-Likelihood:                -72221.
# No. Observations:              134489   AIC:                         1.444e+05
# Df Residuals:                  134485   BIC:                         1.445e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.0229      0.003     -7.676      0.000      -0.029      -0.017
# days_from_event                -0.0002      0.000     -1.900      0.057      -0.001    7.76e-06
# after_event                     0.0863      0.005     18.850      0.000       0.077       0.095
# after_event:days_from_event    -0.0004      0.000     -2.274      0.023      -0.001   -6.17e-05
# ==============================================================================
# Omnibus:                      516.717   Durbin-Watson:                   1.629
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              394.671
# Skew:                           0.031   Prob(JB):                     1.99e-86
# Kurtosis:                       2.742   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    neg   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     607.6
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:31:03   Log-Likelihood:             1.1451e+05
# No. Observations:              134489   AIC:                        -2.290e+05
# Df Residuals:                  134485   BIC:                        -2.290e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0871      0.001    116.947      0.000       0.086       0.089
# days_from_event                 0.0007   3.24e-05     20.169      0.000       0.001       0.001
# after_event                    -0.0310      0.001    -27.136      0.000      -0.033      -0.029
# after_event:days_from_event    -0.0008    4.9e-05    -16.457      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                    43390.096   Durbin-Watson:                   1.669
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           122184.606
# Skew:                           1.735   Prob(JB):                         0.00
# Kurtosis:                       6.124   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pos   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     139.9
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):           1.68e-90
# Time:                        18:31:03   Log-Likelihood:             1.1705e+05
# No. Observations:              134489   AIC:                        -2.341e+05
# Df Residuals:                  134485   BIC:                        -2.340e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0707      0.001     96.771      0.000       0.069       0.072
# days_from_event                 0.0003   3.18e-05      8.189      0.000       0.000       0.000
# after_event                     0.0088      0.001      7.830      0.000       0.007       0.011
# after_event:days_from_event    -0.0009   4.81e-05    -19.499      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                    38477.684   Durbin-Watson:                   1.683
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            93118.034
# Skew:                           1.608   Prob(JB):                         0.00
# Kurtosis:                       5.504   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Angry   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     286.8
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          1.41e-185
# Time:                        18:31:03   Log-Likelihood:                 43686.
# No. Observations:              134489   AIC:                        -8.736e+04
# Df Residuals:                  134485   BIC:                        -8.732e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0298      0.001     23.646      0.000       0.027       0.032
# days_from_event                -0.0005   5.49e-05     -9.901      0.000      -0.001      -0.000
# after_event                    -0.0051      0.002     -2.642      0.008      -0.009      -0.001
# after_event:days_from_event     0.0020    8.3e-05     24.089      0.000       0.002       0.002
# ==============================================================================
# Omnibus:                   113927.203   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2287709.615
# Skew:                           4.236   Prob(JB):                         0.00
# Kurtosis:                      21.343   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Sad   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     209.2
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          2.29e-135
# Time:                        18:31:03   Log-Likelihood:                -26314.
# No. Observations:              134489   AIC:                         5.264e+04
# Df Residuals:                  134485   BIC:                         5.267e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1331      0.002     62.693      0.000       0.129       0.137
# days_from_event                -0.0014   9.24e-05    -15.135      0.000      -0.002      -0.001
# after_event                     0.0416      0.003     12.780      0.000       0.035       0.048
# after_event:days_from_event    -0.0002      0.000     -1.759      0.079      -0.001     2.8e-05
# ==============================================================================
# Omnibus:                    44079.202   Durbin-Watson:                   1.739
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           109107.696
# Skew:                           1.872   Prob(JB):                         0.00
# Kurtosis:                       5.334   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Surprise   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     1107.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:31:03   Log-Likelihood:                -23897.
# No. Observations:              134489   AIC:                         4.780e+04
# Df Residuals:                  134485   BIC:                         4.784e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1070      0.002     51.330      0.000       0.103       0.111
# days_from_event                -0.0005   9.07e-05     -5.404      0.000      -0.001      -0.000
# after_event                    -0.0395      0.003    -12.353      0.000      -0.046      -0.033
# after_event:days_from_event     0.0054      0.000     39.149      0.000       0.005       0.006
# ==============================================================================
# Omnibus:                    47460.487   Durbin-Watson:                   1.647
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           128764.905
# Skew:                           1.961   Prob(JB):                         0.00
# Kurtosis:                       5.757   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fear   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     386.4
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          6.60e-250
# Time:                        18:31:03   Log-Likelihood:                -50066.
# No. Observations:              134489   AIC:                         1.001e+05
# Df Residuals:                  134485   BIC:                         1.002e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2200      0.003     86.852      0.000       0.215       0.225
# days_from_event                 0.0008      0.000      7.587      0.000       0.001       0.001
# after_event                     0.0490      0.004     12.631      0.000       0.041       0.057
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1428      0.006     24.508      0.000       0.131       0.154
# days_from_event                 0.0124      0.001     12.542      0.000       0.011       0.014
# after_event                    -0.1641      0.007    -22.027      0.000      -0.179      -0.150
# after_event:days_from_event    -0.0118      0.001     -8.980      0.000      -0.014      -0.009
# ==============================================================================
# Omnibus:                       80.925   Durbin-Watson:                   1.687
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.017
# Skew:                           0.083   Prob(JB):                     6.95e-18
# Kurtosis:                       2.901   Cond. No.                         33.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    neg   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     215.3
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          8.99e-139
# Time:                        18:31:42   Log-Likelihood:                 41410.
# No. Observations:               50341   AIC:                        -8.281e+04
# Df Residuals:                   50337   BIC:                        -8.278e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0654      0.002     41.665      0.000       0.062       0.069
# days_from_event                 0.0018      0.000      6.592      0.000       0.001       0.002
# after_event                     0.0258      0.002     12.831      0.000       0.022       0.030
# after_event:days_from_event    -0.0065      0.000    -18.315      0.000      -0.007      -0.006
# ==============================================================================
# Omnibus:                    17726.663   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            55266.171
# Skew:                           1.852   Prob(JB):                         0.00
# Kurtosis:                       6.554   Cond. No.                         33.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pos   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     507.6
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:31:42   Log-Likelihood:                 42806.
# No. Observations:               50341   AIC:                        -8.560e+04
# Df Residuals:                   50337   BIC:                        -8.557e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1156      0.002     75.660      0.000       0.113       0.119
# days_from_event                 0.0068      0.000     26.250      0.000       0.006       0.007
# after_event                    -0.0442      0.002    -22.646      0.000      -0.048      -0.040
# after_event:days_from_event    -0.0100      0.000    -29.105      0.000      -0.011      -0.009
# ==============================================================================
# Omnibus:                    16603.545   Durbin-Watson:                   1.798
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            47950.028
# Skew:                           1.762   Prob(JB):                         0.00
# Kurtosis:                       6.231   Cond. No.                         33.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Angry   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     95.26
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):           1.78e-61
# Time:                        18:31:42   Log-Likelihood:                 17715.
# No. Observations:               50341   AIC:                        -3.542e+04
# Df Residuals:                   50337   BIC:                        -3.539e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0057      0.003      2.279      0.023       0.001       0.011
# days_from_event                -0.0070      0.000    -16.425      0.000      -0.008      -0.006
# after_event                     0.0299      0.003      9.292      0.000       0.024       0.036
# after_event:days_from_event     0.0072      0.001     12.741      0.000       0.006       0.008
# ==============================================================================
# Omnibus:                    47126.908   Durbin-Watson:                   1.748
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1301890.390
# Skew:                           4.802   Prob(JB):                         0.00
# Kurtosis:                      25.988   Cond. No.                         33.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Sad   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     174.5
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          1.55e-112
# Time:                        18:31:42   Log-Likelihood:                -6781.1
# No. Observations:               50341   AIC:                         1.357e+04
# Df Residuals:                   50337   BIC:                         1.361e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2117      0.004     51.752      0.000       0.204       0.220
# days_from_event                 0.0083      0.001     11.930      0.000       0.007       0.010
# after_event                    -0.0857      0.005    -16.388      0.000      -0.096      -0.075
# after_event:days_from_event    -0.0096      0.001    -10.393      0.000      -0.011      -0.008
# ==============================================================================
# Omnibus:                    18993.112   Durbin-Watson:                   1.790
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            57306.145
# Skew:                           2.035   Prob(JB):                         0.00
# Kurtosis:                       6.278   Cond. No.                         33.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Surprise   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     2602.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:31:42   Log-Likelihood:                -11971.
# No. Observations:               50341   AIC:                         2.395e+04
# Df Residuals:                   50337   BIC:                         2.398e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0007      0.005      0.149      0.881      -0.008       0.010
# days_from_event                -0.0504      0.001    -65.275      0.000      -0.052      -0.049
# after_event                     0.0932      0.006     16.074      0.000       0.082       0.105
# after_event:days_from_event     0.0520      0.001     50.775      0.000       0.050       0.054
# ==============================================================================
# Omnibus:                    12492.804   Durbin-Watson:                   1.682
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25709.407
# Skew:                           1.488   Prob(JB):                         0.00
# Kurtosis:                       4.844   Cond. No.                         33.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fear   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     1165.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:31:43   Log-Likelihood:                -22152.
# No. Observations:               50341   AIC:                         4.431e+04
# Df Residuals:                   50337   BIC:                         4.435e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.4179      0.006     75.291      0.000       0.407       0.429
# days_from_event                 0.0343      0.001     36.271      0.000       0.032       0.036
# after_event                     0.0191      0.007      2.692      0.007       0.005       0.033
# after_event:days_from_event    -0.0724      0.001    -57.698      0.000      -0.075      -0.070
# ==============================================================================
# Omnibus:                     6674.744   Durbin-Watson:                   1.715
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9551.744
# Skew:                           1.059   Prob(JB):                         0.00
# Kurtosis:                       2.740   Cond. No.                         33.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Happy   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     257.7
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          5.47e-166
# Time:                        18:31:43   Log-Likelihood:                 7605.3
# No. Observations:               50341   AIC:                        -1.520e+04
# Df Residuals:                   50337   BIC:                        -1.517e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1443      0.003     46.947      0.000       0.138       0.150
# days_from_event                 0.0071      0.001     13.527      0.000       0.006       0.008
# after_event                    -0.0856      0.004    -21.780      0.000      -0.093      -0.078
# after_event:days_from_event    -0.0064      0.001     -9.168      0.000      -0.008      -0.005
# ==============================================================================
# Omnibus:                    30850.675   Durbin-Watson:                   1.796
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           251577.301
# Skew:                           2.981   Prob(JB):                         0.00
# Kurtosis:                      12.187   Cond. No.                         33.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fin_df.columns
# Out:
# Index(['tweet_id', 'text', 'author_id', 'geo', 'created_at', 'lang',
#        'retweet_count', 'reply_count', 'like_count', 'quote_count',
#        'author_location', 'country', 'query', 'username', 'location', 'name',
#        'country2', 'neg', 'neu', 'pos', 'compound', 'Happy', 'Angry',
#        'Surprise', 'Sad', 'Fear', 'date', 'created_at_date', 'after_event',
#        'days_from_event'],
#       dtype='object')

# %%
## Adding covariates
indices = [1, 6, 13, 14]

for cutoff_index in indices:
    fin_df = df_en.copy()

    date0 = jump_dates[cutoff_index - 1]
    date1 = jump_dates[cutoff_index]
    date2 = jump_dates[cutoff_index + 1]
    
    days1 = int(str(np.datetime64(date1) - np.datetime64(date0)).replace(' days', ''))
    days2 = int(str(np.datetime64(date2) - np.datetime64(date1)).replace(' days', ''))

    window = min(days1, days2)

    fin_df = fin_df[(fin_df['created_at_date']>np.datetime64(date0))&
                    (fin_df['created_at_date']<np.datetime64(date2))]

    fin_df['after_event'] = fin_df.apply(lambda x: event_occured(x['created_at_date'], str(date1)), axis = 1)
    fin_df['days_from_event'] = fin_df.apply(lambda x: days_from_event(x['created_at_date'], str(date1)), axis = 1)
    
    fin_df['after_event'] = fin_df.apply(lambda x: event_occured(x['created_at_date'], str(date1)), axis = 1)
    fin_df['days_from_event'] = fin_df.apply(lambda x: days_from_event(x['created_at_date'], str(date1)), axis = 1)
    
    reg_df = fin_df[(fin_df['days_from_event'] >= -window)
                &(fin_df['days_from_event'] <= window)]

    for target in ['compound', 'neg', 'pos', 'Angry', 'Sad', 'Surprise', 'Fear', 'Happy']:

        result = smf.ols(formula = f"{target} ~ days_from_event + after_event + after_event * days_from_event + retweet_count + reply_count + like_count + quote_count", 
                         data = reg_df).fit()
        print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               compound   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     3128.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:33:26   Log-Likelihood:                -11048.
# No. Observations:               89696   AIC:                         2.211e+04
# Df Residuals:                   89688   BIC:                         2.219e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0827      0.005     17.498      0.000       0.073       0.092
# days_from_event                 0.0081      0.002      4.998      0.000       0.005       0.011
# after_event                     0.1929      0.006     33.296      0.000       0.182       0.204
# after_event:days_from_event    -0.0856      0.002    -45.167      0.000      -0.089      -0.082
# retweet_count                1.238e-05    8.7e-08    142.206      0.000    1.22e-05    1.25e-05
# reply_count                  7.607e-06      0.000      0.037      0.970      -0.000       0.000
# like_count                  -4.166e-06   3.37e-06     -1.238      0.216   -1.08e-05    2.43e-06
# quote_count                  4.753e-05   6.98e-05      0.681      0.496   -8.92e-05       0.000
# ==============================================================================
# Omnibus:                     7538.029   Durbin-Watson:                   1.776
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24301.368
# Skew:                           0.424   Prob(JB):                         0.00
# Kurtosis:                       5.405   Cond. No.                     1.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    neg   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     716.8
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:33:26   Log-Likelihood:             1.1607e+05
# No. Observations:               89696   AIC:                        -2.321e+05
# Df Residuals:                   89688   BIC:                        -2.320e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0065      0.001      5.700      0.000       0.004       0.009
# days_from_event                -0.0071      0.000    -18.019      0.000      -0.008      -0.006
# after_event                     0.0135      0.001      9.592      0.000       0.011       0.016
# after_event:days_from_event     0.0114      0.000     24.740      0.000       0.010       0.012
# retweet_count               -1.424e-06   2.11e-08    -67.474      0.000   -1.47e-06   -1.38e-06
# reply_count                     0.0002   4.95e-05      4.021      0.000       0.000       0.000
# like_count                  -2.127e-06   8.16e-07     -2.607      0.009   -3.73e-06   -5.28e-07
# quote_count                 -5.905e-05   1.69e-05     -3.491      0.000   -9.22e-05   -2.59e-05
# ==============================================================================
# Omnibus:                    78378.706   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2292470.056
# Skew:                           4.261   Prob(JB):                         0.00
# Kurtosis:                      26.255   Cond. No.                     1.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pos   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     976.3
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:33:26   Log-Likelihood:                 89259.
# No. Observations:               89696   AIC:                        -1.785e+05
# Df Residuals:                   89688   BIC:                        -1.784e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0459      0.002     29.719      0.000       0.043       0.049
# days_from_event                -0.0016      0.001     -2.947      0.003      -0.003      -0.001
# after_event                     0.0590      0.002     31.146      0.000       0.055       0.063
# after_event:days_from_event    -0.0171      0.001    -27.534      0.000      -0.018      -0.016
# retweet_count                2.106e-06   2.85e-08     74.022      0.000    2.05e-06    2.16e-06
# reply_count                     0.0002   6.68e-05      2.659      0.008    4.67e-05       0.000
# like_count                  -2.583e-06    1.1e-06     -2.349      0.019   -4.74e-06   -4.28e-07
# quote_count                 -4.577e-05   2.28e-05     -2.007      0.045   -9.05e-05   -1.07e-06
# ==============================================================================
# Omnibus:                    41029.010   Durbin-Watson:                   1.701
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           206032.624
# Skew:                           2.233   Prob(JB):                         0.00
# Kurtosis:                       8.931   Cond. No.                     1.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Angry   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     173.0
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          1.89e-255
# Time:                        18:33:26   Log-Likelihood:                 92201.
# No. Observations:               89696   AIC:                        -1.844e+05
# Df Residuals:                   89688   BIC:                        -1.843e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.0035      0.001     -2.325      0.020      -0.006      -0.001
# days_from_event                -0.0070      0.001    -13.522      0.000      -0.008      -0.006
# after_event                     0.0144      0.002      7.864      0.000       0.011       0.018
# after_event:days_from_event     0.0097      0.001     16.139      0.000       0.008       0.011
# retweet_count               -8.387e-07   2.75e-08    -30.462      0.000   -8.93e-07   -7.85e-07
# reply_count                     0.0004   6.46e-05      5.478      0.000       0.000       0.000
# like_count                   -3.24e-06   1.06e-06     -3.044      0.002   -5.33e-06   -1.15e-06
# quote_count                 -8.114e-05   2.21e-05     -3.676      0.000      -0.000   -3.79e-05
# ==============================================================================
# Omnibus:                   122622.419   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         22342152.588
# Skew:                           8.182   Prob(JB):                         0.00
# Kurtosis:                      78.567   Cond. No.                     1.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Sad   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     4287.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:33:26   Log-Likelihood:                 5379.9
# No. Observations:               89696   AIC:                        -1.074e+04
# Df Residuals:                   89688   BIC:                        -1.067e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2565      0.004     65.214      0.000       0.249       0.264
# days_from_event                 0.0227      0.001     16.731      0.000       0.020       0.025
# after_event                    -0.1914      0.005    -39.682      0.000      -0.201      -0.182
# after_event:days_from_event     0.0151      0.002      9.575      0.000       0.012       0.018
# retweet_count                9.688e-06   7.25e-08    133.662      0.000    9.55e-06    9.83e-06
# reply_count                     0.0003      0.000      1.960      0.050   -4.82e-08       0.001
# like_count                  -4.439e-06    2.8e-06     -1.584      0.113   -9.93e-06    1.05e-06
# quote_count                    -0.0001   5.81e-05     -2.105      0.035      -0.000   -8.44e-06
# ==============================================================================
# Omnibus:                    21296.103   Durbin-Watson:                   1.798
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            51302.183
# Skew:                           1.324   Prob(JB):                         0.00
# Kurtosis:                       5.592   Cond. No.                     1.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Surprise   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     1636.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:33:27   Log-Likelihood:                -18181.
# No. Observations:               89696   AIC:                         3.638e+04
# Df Residuals:                   89688   BIC:                         3.645e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1309      0.005     25.589      0.000       0.121       0.141
# days_from_event                 0.0058      0.002      3.293      0.001       0.002       0.009
# after_event                    -0.1022      0.006    -16.296      0.000      -0.115      -0.090
# after_event:days_from_event     0.0628      0.002     30.599      0.000       0.059       0.067
# retweet_count               -9.298e-06   9.43e-08    -98.645      0.000   -9.48e-06   -9.11e-06
# reply_count                    -0.0005      0.000     -2.244      0.025      -0.001   -6.28e-05
# like_count                   5.095e-06   3.64e-06      1.398      0.162   -2.05e-06    1.22e-05
# quote_count                     0.0002   7.56e-05      2.241      0.025    2.12e-05       0.000
# ==============================================================================
# Omnibus:                    25862.867   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            58338.977
# Skew:                           1.683   Prob(JB):                         0.00
# Kurtosis:                       5.070   Cond. No.                     1.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fear   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     967.9
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:33:27   Log-Likelihood:                -17869.
# No. Observations:               89696   AIC:                         3.575e+04
# Df Residuals:                   89688   BIC:                         3.583e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2974      0.005     58.346      0.000       0.287       0.307
# days_from_event                 0.0214      0.002     12.178      0.000       0.018       0.025
# after_event                    -0.0304      0.006     -4.871      0.000      -0.043      -0.018
# after_event:days_from_event    -0.0174      0.002     -8.527      0.000      -0.021      -0.013
# retweet_count               -7.238e-06   9.39e-08    -77.060      0.000   -7.42e-06   -7.05e-06
# reply_count                 -3.625e-05      0.000     -0.164      0.869      -0.000       0.000
# like_count                  -1.051e-07   3.63e-06     -0.029      0.977   -7.22e-06    7.01e-06
# quote_count                  2.571e-05   7.53e-05      0.342      0.733      -0.000       0.000
# ==============================================================================
# Omnibus:                    11251.139   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16052.105
# Skew:                           1.029   Prob(JB):                         0.00
# Kurtosis:                       3.241   Cond. No.                     1.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Happy   R-squared:                       0.383
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     7947.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:33:27   Log-Likelihood:                 23356.
# No. Observations:               89696   AIC:                        -4.670e+04
# Df Residuals:                   89688   BIC:                        -4.662e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.0098      0.003     -3.056      0.002      -0.016      -0.004
# days_from_event                -0.0195      0.001    -17.531      0.000      -0.022      -0.017
# after_event                     0.0418      0.004     10.594      0.000       0.034       0.050
# after_event:days_from_event     0.0250      0.001     19.389      0.000       0.023       0.028
# retweet_count                1.221e-05   5.93e-08    205.902      0.000    1.21e-05    1.23e-05
# reply_count                     0.0004      0.000      3.164      0.002       0.000       0.001
# like_count                  -6.226e-06   2.29e-06     -2.715      0.007   -1.07e-05   -1.73e-06
# quote_count                    -0.0001   4.76e-05     -2.954      0.003      -0.000   -4.73e-05
# ==============================================================================
# Omnibus:                    57085.217   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           639146.114
# Skew:                           2.984   Prob(JB):                         0.00
# Kurtosis:                      14.636   Cond. No.                     1.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               compound   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     1964.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:02   Log-Likelihood:            -1.8842e+05
# No. Observations:              380462   AIC:                         3.769e+05
# Df Residuals:                  380454   BIC:                         3.769e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.1348      0.003    -45.908      0.000      -0.141      -0.129
# days_from_event                 0.0370      0.002     21.268      0.000       0.034       0.040
# after_event                     0.0692      0.003     21.428      0.000       0.063       0.076
# after_event:days_from_event    -0.0394      0.003    -14.491      0.000      -0.045      -0.034
# retweet_count                1.765e-06   4.84e-08     36.469      0.000    1.67e-06    1.86e-06
# reply_count                     0.0001   6.57e-05      1.637      0.102   -2.12e-05       0.000
# like_count                   9.758e-07   2.53e-06      0.385      0.700   -3.99e-06    5.94e-06
# quote_count                    -0.0002   7.54e-05     -1.995      0.046      -0.000   -2.65e-06
# ==============================================================================
# Omnibus:                     7133.868   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4131.096
# Skew:                           0.078   Prob(JB):                         0.00
# Kurtosis:                       2.514   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    neg   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     929.4
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:03   Log-Likelihood:             3.2064e+05
# No. Observations:              380462   AIC:                        -6.413e+05
# Df Residuals:                  380454   BIC:                        -6.412e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1172      0.001    152.114      0.000       0.116       0.119
# days_from_event                 0.0042      0.000      9.158      0.000       0.003       0.005
# after_event                    -0.0316      0.001    -37.286      0.000      -0.033      -0.030
# after_event:days_from_event     0.0050      0.001      7.059      0.000       0.004       0.006
# retweet_count                 7.78e-07   1.27e-08     61.257      0.000    7.53e-07    8.03e-07
# reply_count                 -2.769e-06   1.72e-05     -0.161      0.872   -3.66e-05     3.1e-05
# like_count                   1.808e-07   6.64e-07      0.272      0.786   -1.12e-06    1.48e-06
# quote_count                  3.412e-06   1.98e-05      0.172      0.863   -3.54e-05    4.22e-05
# ==============================================================================
# Omnibus:                    61500.965   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           108875.540
# Skew:                           1.047   Prob(JB):                         0.00
# Kurtosis:                       4.575   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pos   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     2036.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:03   Log-Likelihood:             4.1574e+05
# No. Observations:              380462   AIC:                        -8.315e+05
# Df Residuals:                  380454   BIC:                        -8.314e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0722      0.001    120.352      0.000       0.071       0.073
# days_from_event                 0.0153      0.000     42.963      0.000       0.015       0.016
# after_event                    -0.0051      0.001     -7.736      0.000      -0.006      -0.004
# after_event:days_from_event    -0.0170      0.001    -30.669      0.000      -0.018      -0.016
# retweet_count                6.472e-07   9.89e-09     65.433      0.000    6.28e-07    6.67e-07
# reply_count                  2.742e-05   1.34e-05      2.042      0.041     1.1e-06    5.37e-05
# like_count                    2.67e-07   5.17e-07      0.516      0.606   -7.47e-07    1.28e-06
# quote_count                 -2.582e-05   1.54e-05     -1.675      0.094    -5.6e-05     4.4e-06
# ==============================================================================
# Omnibus:                    98469.545   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           238257.693
# Skew:                           1.444   Prob(JB):                         0.00
# Kurtosis:                       5.587   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Angry   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     803.6
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:04   Log-Likelihood:             1.6794e+05
# No. Observations:              380462   AIC:                        -3.359e+05
# Df Residuals:                  380454   BIC:                        -3.358e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0745      0.001     64.739      0.000       0.072       0.077
# days_from_event                 0.0102      0.001     14.987      0.000       0.009       0.012
# after_event                    -0.0201      0.001    -15.878      0.000      -0.023      -0.018
# after_event:days_from_event    -0.0114      0.001    -10.732      0.000      -0.014      -0.009
# retweet_count               -1.236e-06    1.9e-08    -65.169      0.000   -1.27e-06    -1.2e-06
# reply_count                  4.044e-05   2.58e-05      1.570      0.116   -1.01e-05    9.09e-05
# like_count                  -7.841e-07   9.92e-07     -0.790      0.430   -2.73e-06    1.16e-06
# quote_count                 -9.811e-06   2.96e-05     -0.332      0.740   -6.78e-05    4.81e-05
# ==============================================================================
# Omnibus:                   325776.608   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7545589.439
# Skew:                           4.238   Prob(JB):                         0.00
# Kurtosis:                      23.103   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Sad   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     3441.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:04   Log-Likelihood:                -66074.
# No. Observations:              380462   AIC:                         1.322e+05
# Df Residuals:                  380454   BIC:                         1.323e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1244      0.002     58.448      0.000       0.120       0.129
# days_from_event                -0.0212      0.001    -16.816      0.000      -0.024      -0.019
# after_event                     0.0510      0.002     21.786      0.000       0.046       0.056
# after_event:days_from_event     0.0396      0.002     20.102      0.000       0.036       0.043
# retweet_count                4.635e-06   3.51e-08    132.064      0.000    4.57e-06     4.7e-06
# reply_count                  7.077e-05   4.77e-05      1.485      0.137   -2.26e-05       0.000
# like_count                  -1.568e-06   1.84e-06     -0.854      0.393   -5.17e-06    2.03e-06
# quote_count                  1.668e-05   5.47e-05      0.305      0.760   -9.05e-05       0.000
# ==============================================================================
# Omnibus:                    80317.115   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144869.663
# Skew:                           1.362   Prob(JB):                         0.00
# Kurtosis:                       4.311   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Surprise   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     194.3
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          5.91e-289
# Time:                        18:35:05   Log-Likelihood:                -90244.
# No. Observations:              380462   AIC:                         1.805e+05
# Df Residuals:                  380454   BIC:                         1.806e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1583      0.002     69.808      0.000       0.154       0.163
# days_from_event                -0.0290      0.001    -21.597      0.000      -0.032      -0.026
# after_event                     0.0353      0.002     14.162      0.000       0.030       0.040
# after_event:days_from_event     0.0289      0.002     13.778      0.000       0.025       0.033
# retweet_count                1.042e-06   3.74e-08     27.876      0.000    9.69e-07    1.12e-06
# reply_count                 -7.434e-05   5.08e-05     -1.464      0.143      -0.000    2.52e-05
# like_count                   2.831e-06   1.96e-06      1.447      0.148      -1e-06    6.67e-06
# quote_count                  1.818e-06   5.83e-05      0.031      0.975      -0.000       0.000
# ==============================================================================
# Omnibus:                    86787.170   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           160085.930
# Skew:                           1.482   Prob(JB):                         0.00
# Kurtosis:                       4.145   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fear   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     336.1
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:06   Log-Likelihood:            -1.3473e+05
# No. Observations:              380462   AIC:                         2.695e+05
# Df Residuals:                  380454   BIC:                         2.696e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2811      0.003    110.270      0.000       0.276       0.286
# days_from_event                -0.0167      0.002    -11.036      0.000      -0.020      -0.014
# after_event                     0.0087      0.003      3.089      0.002       0.003       0.014
# after_event:days_from_event     0.0335      0.002     14.192      0.000       0.029       0.038
# retweet_count               -1.754e-06    4.2e-08    -41.729      0.000   -1.84e-06   -1.67e-06
# reply_count                   3.12e-05   5.71e-05      0.547      0.585   -8.07e-05       0.000
# like_count                  -1.657e-06    2.2e-06     -0.754      0.451   -5.97e-06    2.65e-06
# quote_count                  2.866e-05   6.55e-05      0.437      0.662   -9.98e-05       0.000
# ==============================================================================
# Omnibus:                    42121.993   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            53589.607
# Skew:                           0.898   Prob(JB):                         0.00
# Kurtosis:                       2.602   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Happy   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     725.4
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:06   Log-Likelihood:             1.7000e+05
# No. Observations:              380462   AIC:                        -3.400e+05
# Df Residuals:                  380454   BIC:                        -3.399e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0408      0.001     35.677      0.000       0.039       0.043
# days_from_event                -0.0150      0.001    -22.179      0.000      -0.016      -0.014
# after_event                     0.0095      0.001      7.577      0.000       0.007       0.012
# after_event:days_from_event     0.0081      0.001      7.676      0.000       0.006       0.010
# retweet_count               -8.443e-07   1.89e-08    -44.741      0.000   -8.81e-07   -8.07e-07
# reply_count                  2.288e-06   2.56e-05      0.089      0.929   -4.79e-05    5.25e-05
# like_count                  -2.591e-07   9.87e-07     -0.263      0.793   -2.19e-06    1.68e-06
# quote_count                 -6.101e-06   2.94e-05     -0.207      0.836   -6.37e-05    5.15e-05
# ==============================================================================
# Omnibus:                   286162.759   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4386001.958
# Skew:                           3.646   Prob(JB):                         0.00
# Kurtosis:                      17.950   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               compound   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     500.6
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:50   Log-Likelihood:                -70939.
# No. Observations:              134489   AIC:                         1.419e+05
# Df Residuals:                  134481   BIC:                         1.420e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.0040      0.003     -1.328      0.184      -0.010       0.002
# days_from_event                -0.0004      0.000     -3.300      0.001      -0.001      -0.000
# after_event                     0.0765      0.005     16.867      0.000       0.068       0.085
# after_event:days_from_event    -0.0001      0.000     -0.749      0.454      -0.001       0.000
# retweet_count               -1.997e-05   3.93e-07    -50.841      0.000   -2.07e-05   -1.92e-05
# reply_count                     0.0001      0.000      0.364      0.716      -0.000       0.001
# like_count                    1.37e-06   4.78e-06      0.286      0.775   -8.01e-06    1.07e-05
# quote_count                    -0.0004      0.000     -0.993      0.321      -0.001       0.000
# ==============================================================================
# Omnibus:                      206.745   Durbin-Watson:                   1.647
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.906
# Skew:                           0.004   Prob(JB):                     4.69e-38
# Kurtosis:                       2.825   Cond. No.                     1.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    neg   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     349.5
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:50   Log-Likelihood:             1.1482e+05
# No. Observations:              134489   AIC:                        -2.296e+05
# Df Residuals:                  134481   BIC:                        -2.295e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0848      0.001    113.149      0.000       0.083       0.086
# days_from_event                 0.0007   3.24e-05     20.876      0.000       0.001       0.001
# after_event                    -0.0298      0.001    -26.130      0.000      -0.032      -0.028
# after_event:days_from_event    -0.0008   4.89e-05    -17.242      0.000      -0.001      -0.001
# retweet_count                2.433e-06   9.87e-08     24.646      0.000    2.24e-06    2.63e-06
# reply_count                     0.0001   7.34e-05      1.962      0.050    1.61e-07       0.000
# like_count                   1.095e-06    1.2e-06      0.911      0.362   -1.26e-06    3.45e-06
# quote_count                 -3.429e-05      0.000     -0.304      0.761      -0.000       0.000
# ==============================================================================
# Omnibus:                    44339.484   Durbin-Watson:                   1.672
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           129004.321
# Skew:                           1.758   Prob(JB):                         0.00
# Kurtosis:                       6.265   Cond. No.                     1.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pos   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     455.2
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:35:50   Log-Likelihood:             1.1841e+05
# ...
# [2] The condition number is large, 8.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pos   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     327.4
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:36:30   Log-Likelihood:                 43177.
# No. Observations:               50341   AIC:                        -8.634e+04
# Df Residuals:                   50333   BIC:                        -8.627e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1193      0.002     78.357      0.000       0.116       0.122
# days_from_event                 0.0062      0.000     23.858      0.000       0.006       0.007
# after_event                    -0.0434      0.002    -22.373      0.000      -0.047      -0.040
# after_event:days_from_event    -0.0094      0.000    -27.299      0.000      -0.010      -0.009
# retweet_count               -8.137e-06   2.98e-07    -27.300      0.000   -8.72e-06   -7.55e-06
# reply_count                  2.767e-05      0.000      0.264      0.792      -0.000       0.000
# like_count                   3.169e-07   1.72e-06      0.184      0.854   -3.06e-06    3.69e-06
# quote_count                    -0.0001      0.000     -0.699      0.484      -0.000       0.000
# ==============================================================================
# Omnibus:                    16084.978   Durbin-Watson:                   1.799
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            45582.894
# Skew:                           1.711   Prob(JB):                         0.00
# Kurtosis:                       6.165   Cond. No.                     8.74e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Angry   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     82.69
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          4.41e-120
# Time:                        18:36:30   Log-Likelihood:                 17861.
# No. Observations:               50341   AIC:                        -3.571e+04
# Df Residuals:                   50333   BIC:                        -3.563e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0096      0.003      3.828      0.000       0.005       0.015
# days_from_event                -0.0077      0.000    -17.951      0.000      -0.009      -0.007
# after_event                     0.0307      0.003      9.586      0.000       0.024       0.037
# after_event:days_from_event     0.0079      0.001     13.962      0.000       0.007       0.009
# retweet_count               -8.408e-06   4.93e-07    -17.060      0.000   -9.37e-06   -7.44e-06
# reply_count                    -0.0001      0.000     -0.646      0.518      -0.000       0.000
# like_count                  -7.563e-07   2.85e-06     -0.266      0.791   -6.34e-06    4.82e-06
# quote_count                     0.0001      0.000      0.441      0.659      -0.000       0.001
# ==============================================================================
# Omnibus:                    46942.621   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1284168.316
# Skew:                           4.776   Prob(JB):                         0.00
# Kurtosis:                      25.825   Cond. No.                     8.74e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Sad   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     78.66
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          4.57e-114
# Time:                        18:36:30   Log-Likelihood:                -6767.6
# No. Observations:               50341   AIC:                         1.355e+04
# Df Residuals:                   50333   BIC:                         1.362e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2126      0.004     51.779      0.000       0.205       0.221
# days_from_event                 0.0081      0.001     11.584      0.000       0.007       0.009
# after_event                    -0.0854      0.005    -16.323      0.000      -0.096      -0.075
# after_event:days_from_event    -0.0094      0.001    -10.144      0.000      -0.011      -0.008
# retweet_count               -2.576e-06   8.04e-07     -3.205      0.001   -4.15e-06      -1e-06
# reply_count                     0.0011      0.000      3.910      0.000       0.001       0.002
# like_count                  -7.362e-07   4.64e-06     -0.159      0.874   -9.84e-06    8.37e-06
# quote_count                    -0.0012      0.000     -2.669      0.008      -0.002      -0.000
# ==============================================================================
# Omnibus:                    18852.703   Durbin-Watson:                   1.789
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            56370.835
# Skew:                           2.024   Prob(JB):                         0.00
# Kurtosis:                       6.239   Cond. No.                     8.74e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Surprise   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     1217.
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:36:30   Log-Likelihood:                -11664.
# No. Observations:               50341   AIC:                         2.334e+04
# Df Residuals:                   50333   BIC:                         2.341e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.0094      0.005     -2.085      0.037      -0.018      -0.001
# days_from_event                -0.0487      0.001    -63.143      0.000      -0.050      -0.047
# after_event                     0.0909      0.006     15.774      0.000       0.080       0.102
# after_event:days_from_event     0.0502      0.001     49.178      0.000       0.048       0.052
# retweet_count                2.199e-05   8.86e-07     24.818      0.000    2.03e-05    2.37e-05
# reply_count                  4.763e-05      0.000      0.153      0.878      -0.001       0.001
# like_count                   3.551e-06   5.12e-06      0.694      0.488   -6.48e-06    1.36e-05
# quote_count                    -0.0005      0.000     -1.080      0.280      -0.001       0.000
# ==============================================================================
# Omnibus:                    13372.956   Durbin-Watson:                   1.696
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29364.957
# Skew:                           1.549   Prob(JB):                         0.00
# Kurtosis:                       5.097   Cond. No.                     8.74e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fear   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     565.1
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:36:31   Log-Likelihood:                -21938.
# No. Observations:               50341   AIC:                         4.389e+04
# Df Residuals:                   50333   BIC:                         4.396e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.4281      0.006     77.125      0.000       0.417       0.439
# days_from_event                 0.0325      0.001     34.393      0.000       0.031       0.034
# after_event                     0.0215      0.007      3.034      0.002       0.008       0.035
# after_event:days_from_event    -0.0705      0.001    -56.314      0.000      -0.073      -0.068
# retweet_count                -2.24e-05   1.09e-06    -20.618      0.000   -2.45e-05   -2.03e-05
# reply_count                     0.0001      0.000      0.307      0.759      -0.001       0.001
# like_count                  -7.404e-06   6.28e-06     -1.179      0.238   -1.97e-05     4.9e-06
# quote_count                     0.0010      0.001      1.604      0.109      -0.000       0.002
# ==============================================================================
# Omnibus:                     6529.871   Durbin-Watson:                   1.728
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9250.083
# Skew:                           1.041   Prob(JB):                         0.00
# Kurtosis:                       2.732   Cond. No.                     8.74e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Happy   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     112.4
# Date:                Tue, 18 Apr 2023   Prob (F-statistic):          2.23e-164
# Time:                        18:36:31   Log-Likelihood:                 7612.3
# No. Observations:               50341   AIC:                        -1.521e+04
# Df Residuals:                   50333   BIC:                        -1.514e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1433      0.003     46.445      0.000       0.137       0.149
# days_from_event                 0.0073      0.001     13.797      0.000       0.006       0.008
# after_event                    -0.0858      0.004    -21.837      0.000      -0.094      -0.078
# after_event:days_from_event    -0.0065      0.001     -9.401      0.000      -0.008      -0.005
# retweet_count                2.125e-06   6.04e-07      3.518      0.000    9.41e-07    3.31e-06
# reply_count                 -9.393e-05      0.000     -0.442      0.658      -0.001       0.000
# like_count                   3.575e-06   3.49e-06      1.024      0.306   -3.27e-06    1.04e-05
# quote_count                    -0.0002      0.000     -0.696      0.486      -0.001       0.000
# ==============================================================================
# Omnibus:                    30986.346   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           255246.818
# Skew:                           2.994   Prob(JB):                         0.00
# Kurtosis:                      12.265   Cond. No.                     8.74e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
slopes_
# Out:
#          start         end     slope  intercept
# 0   2022-11-01  2022-11-17 -0.004078   0.104056
# 1   2022-11-17  2022-11-22  0.053575  -0.012284
# 2   2022-11-22  2022-11-23  0.000000   0.142909
# 3   2022-11-23  2022-11-27 -0.027823   0.143518
# 4   2022-11-27  2022-11-28  0.000000   0.087245
# 5   2022-11-28  2022-12-02  0.004347   0.043131
# 6   2022-12-02  2022-12-04 -0.014309   0.041802
# 7   2022-12-04  2022-12-05  0.000000   0.039749
# 8   2022-12-05  2022-12-14 -0.017526   0.175185
# 9   2022-12-14  2022-12-16 -0.003608   0.047129
# 10  2022-12-16  2023-01-05  0.000744   0.080114
# 11  2023-01-05  2023-01-06  0.000000   0.026008
# 12  2023-01-06  2023-02-14  0.002275   0.045579
# 13  2023-02-14  2023-03-31  0.000684   0.101143
# 14  2023-03-31  2023-04-10  0.000715   0.058667
